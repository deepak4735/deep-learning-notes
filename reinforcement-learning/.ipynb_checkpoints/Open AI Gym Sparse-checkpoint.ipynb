# %% [markdown]
# # Open AI Gym
#
# The environment's .step() function returns an:
# 1. Observation (Object)- Object representing environment
# 2. Reward (Float)- Reward from previous action
# 3. Done (Boolean) - Whether to reset the environment again.
# 4. Info (dict) - Diagnostic information for debugging.
#
#
# Call env.reset() to start the process and return an intial observation
#
# env.action_space() and env.observation_space() describe the format of valid actions and observations.

# %%
import gym

# %%
env = gym.make('CartPole-v0')
#MoutainCar-v0
#MsPacman-v0 - atari
#Hopper -v1 - MuJoCo

for i_episode in range(20):
    observation = env.reset()
    for t in range(100):
        env.render()
        print(observation)
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        if done:
            print("Episode finished after % timesteps", t+1)
            break
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# [-0.02196799 -0.02576163 -0.00826192  0.01357678]
# [-0.02248322 -0.22076413 -0.00799038  0.30364156]
# [-0.0268985  -0.02552922 -0.00191755  0.0084494 ]
# [-0.02740909  0.16962018 -0.00174857 -0.28483792]
# [-0.02401668 -0.02547679 -0.00744532  0.00729301]
# [-0.02452622  0.16975115 -0.00729946 -0.28772968]
# [-0.0211312   0.36497643 -0.01305406 -0.58270583]
# [-0.01383167  0.56027881 -0.02470817 -0.87947223]
# [-0.00262609  0.7557276  -0.04229762 -1.17981938]
# [ 0.01248846  0.95137242 -0.06589401 -1.48545592]
# [ 0.03151591  1.14723276 -0.09560312 -1.79796767]
# [ 0.05446056  1.34328569 -0.13156248 -2.11876867]
# [ 0.08132628  1.14969806 -0.17393785 -1.86946455]
# Episode finished after % timesteps 13
# [ 0.01552367  0.03269076 -0.00952214  0.0383134 ]
# [ 0.01617749  0.22794795 -0.00875587 -0.25735858]
# [ 0.02073644  0.0329521  -0.01390304  0.0325498 ]
# [ 0.02139549 -0.16196775 -0.01325205  0.32081395]
# [ 0.01815613 -0.35689849 -0.00683577  0.6092884 ]
# [ 0.01101816 -0.55192422  0.00535     0.89981046]
# [ -2.03227112e-05  -7.47118264e-01   2.33462086e-02   1.19417022e+00]
# [-0.01496269 -0.5523063   0.04722961  0.90889507]
# [-0.02600881 -0.74803461  0.06540751  1.2160405 ]
# [-0.04096951 -0.55381444  0.08972832  0.9445493 ]
# [-0.0520458  -0.3600083   0.10861931  0.68135432]
# [-0.05924596 -0.55645777  0.1222464   1.00616324]
# [-0.07037512 -0.75298123  0.14236966  1.33459951]
# [-0.08543474 -0.55991144  0.16906165  1.08964031]
# [-0.09663297 -0.36737209  0.19085446  0.8544165 ]
# [-0.10398041 -0.17529194  0.20794279  0.627299  ]
# Episode finished after % timesteps 16
# [ 0.03316948 -0.00527383 -0.01523652  0.02842449]
# [ 0.033064   -0.200174   -0.01466803  0.31626145]
# [ 0.02906052 -0.00484622 -0.0083428   0.01898906]
# [ 0.0289636  -0.19984754 -0.00796302  0.3090281 ]
# [ 0.02496665 -0.00461304 -0.00178246  0.01384454]
# [ 0.02487439 -0.19970939 -0.00150557  0.30596454]
# [ 0.0208802  -0.00456601  0.00461372  0.01280718]
# [ 0.02078888  0.19048947  0.00486987 -0.2784165 ]
# [ 0.02459867 -0.00470162 -0.00069846  0.01579839]
# [ 0.02450464  0.19043035 -0.00038249 -0.27710483]
# [ 0.04065162  0.36561447 -0.09157002 -0.65910557]
# [ 0.04796391  0.5618835  -0.10475214 -0.97915966]
# [ 0.05920158  0.36830993 -0.12433533 -0.72113175]
# [ 0.06656778  0.17510731 -0.13875796 -0.47002549]
# [ 0.07006993 -0.01780986 -0.14815847 -0.22409512]
# [ 0.06971373  0.17908477 -0.15264038 -0.55960088]
# [ 0.07329543 -0.01360244 -0.16383239 -0.31863282]
# [ 0.07302338 -0.20605816 -0.17020505 -0.08176641]
# [ 0.06890222 -0.00895697 -0.17184038 -0.42294505]
# [ 0.06872308  0.18812968 -0.18029928 -0.76449372]
# [ 0.07248567  0.38521573 -0.19558915 -1.10805192]
# Episode finished after % timesteps 29
# [ 0.00443985 -0.0297597  -0.00211441  0.04164177]
# [ 0.00384466 -0.22485126 -0.00128158  0.33365683]
# [-0.00065236 -0.0297111   0.00539156  0.04057004]
# [-0.00124659 -0.22490994  0.00620296  0.33494916]
# [-0.00574479 -0.42011962  0.01290194  0.62958171]
# [-0.01414718 -0.61541922  0.02549358  0.92629979]
# [-0.02645556 -0.810876    0.04401957  1.22688398]
# [-0.04267308 -0.61634748  0.06855725  0.94831143]
# [-0.05500003 -0.42221222  0.08752348  0.67793266]
# [-0.06344428 -0.22840824  0.10108213  0.41403851]
# [-0.06801244 -0.42480679  0.1093629   0.73680014]
# [-0.07650858 -0.23135161  0.12409891  0.4804396 ]
# [-0.08113561 -0.42798678  0.1337077   0.80951556]
# [-0.08969534 -0.62466254  0.14989801  1.14108908]
# [-0.1021886  -0.43178333  0.17271979  0.89891976]
# [-0.11082426 -0.23936982  0.19069819  0.6651214 ]
# [-0.11561166 -0.04733994  0.20400061  0.43802429]
# Episode finished after % timesteps 17
# [ 0.01755937  0.01077066  0.04489174 -0.04312381]
# [ 0.01777478  0.20522109  0.04402926 -0.32131186]
# [ 0.0218792   0.39968928  0.03760303 -0.59979103]
# [ 0.02987299  0.20406197  0.02560721 -0.29550483]
# [ 0.03395423  0.0085845   0.01969711  0.00514295]
# [ 0.03412592  0.20341851  0.01979997 -0.28126079]
# [ 0.03819429  0.39825251  0.01417475 -0.5676337 ]
# [ 0.04615934  0.59317279  0.00282208 -0.85581752]
# [ 0.05802279  0.78825617 -0.01429427 -1.14761173]
# [ 0.07378792  0.98356181 -0.03724651 -1.44474263]
# [ 0.09345915  1.17912177 -0.06614136 -1.74882705]
# [ 0.11704159  1.37492972 -0.1011179  -2.06132816]
# [ 0.14454018  1.57092739 -0.14234446 -2.38350093]
# [ 0.17595873  1.7669883  -0.19001448 -2.71632598]
# Episode finished after % timesteps 14
# [ 0.02340453 -0.04482546  0.00454253 -0.00508961]
# [ 0.02250802 -0.24001226  0.00444073  0.28902307]
# [ 0.01770777 -0.43519725  0.0102212   0.58310325]
# [ 0.00900383 -0.6304609   0.02188326  0.87898839]
# [-0.00360539 -0.82587325  0.03946303  1.1784699 ]
# [-0.02012285 -0.63128537  0.06303243  0.89841446]
# [-0.03274856 -0.43707179  0.08100072  0.62619187]
# [ 0.03188709  0.57948416 -0.12833263 -1.07012361]
# [ 0.04347677  0.77604789 -0.1497351  -1.4001709 ]
# [ 0.05899773  0.58307031 -0.17773852 -1.15780128]
# [ 0.07065913  0.78000626 -0.20089454 -1.50053186]
# Episode finished after % timesteps 17
# [ 0.03648333 -0.01063014 -0.0358568  -0.0137386 ]
# [ 0.03627073  0.1849872  -0.03613157 -0.31751565]
# [ 0.03997047  0.38060465 -0.04248189 -0.62137069]
# [ 0.04758257  0.18610089 -0.0549093  -0.34236419]
# [ 0.05130458 -0.00819862 -0.06175658 -0.06748941]
# [ 0.05114061  0.18775188 -0.06310637 -0.37899972]
# [ 0.05489565  0.3837106  -0.07068637 -0.69089367]
# [ 0.06256986  0.18963697 -0.08450424 -0.42127469]
# [ 0.0663626   0.38584818 -0.09292973 -0.73935596]
# [ 0.07407956  0.58212206 -0.10771685 -1.05977848]
# [ 0.08572201  0.77849303 -0.12891242 -1.38423528]
# [ 0.10129187  0.97496546 -0.15659713 -1.71429388]
# [ 0.12079118  1.17149978 -0.190883   -2.05133969]
# Episode finished after % timesteps 13

# %%
from gym import spaces

env = gym.make('MountainCar-v0')
print(env.action_space)
space = spaces.Discrete(8)
x = space.sample()
print(x)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Discrete(3)
# 4

# %%
# provides parameters for a task, 
# num of trials and max num of steps
print(gym.envs.registry.all())

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-5a9f78d4e9c1> in <module>()
#       3 from keras.layers import Dense
#       4
# ----> 5 onclick()
#
# NameError: name 'onclick' is not defined

# %%
# %matplotlib inline

import gym 

import numpy as np
import matplotlib.pyplot as plt

from ipywidgets import widgets
from IPython.display import display, HTML

from matplotlib import animation

def leftclicked(something):
    """ Apply a force to the left of the cart"""
    onclick(0)

def rightclicked(something):
    """ Apply a force to the right of the cart"""
    onclick(1)
    
def display_buttons():
    """ Display the buttons you can use to apply a force to the cart """
    left = widgets.Button(description="<")
    right = widgets.Button(description=">")
    display(left, right)
    
    left.on_click(leftclicked)
    right.on_click(rightclicked)

# Create the environment and display the initial state
env = gym.make('CartPole-v0')
observation = env.reset()
firstframe = env.render(mode = 'rgb_array')
fig,ax = plt.subplots()
im = ax.imshow(firstframe) 

# Show the buttons to control the cart
display_buttons()


# Function that defines what happens when you click one of the buttons
frames = []
def onclick(action):
    global frames
    result = env.step(action)
    print(result)
    observation, reward, done, info = result
    frame = env.render(mode = 'rgb_array')
    im.set_data(frame)
    frames.append(frame)
    if done:
        env.reset()
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# Widget Javascript not detected.  It may not be installed or enabled properly.
# (array([-0.00731047, -0.16605483, -0.04314794,  0.31042143]), 1.0, False, {})
# (array([-0.01063157,  0.02965446, -0.03693951,  0.00444916]), 1.0, False, {})
# (array([-0.01003848,  0.22528617, -0.03685053, -0.29965596]), 1.0, False, {})
# (array([-0.00553276,  0.42091348, -0.04284365, -0.60372931]), 1.0, False, {})
# (array([ 0.00288551,  0.61660762, -0.05491823, -0.90959333]), 1.0, False, {})
# (array([ 0.01521766,  0.81242812, -0.0731101 , -1.21901909]), 1.0, False, {})
# (array([ 0.03146623,  1.00841243, -0.09749048, -1.53368547]), 1.0, False, {})
# (array([ 0.05163447,  1.20456435, -0.12816419, -1.85513304]), 1.0, False, {})
# (array([ 0.07572576,  1.40084054, -0.16526685, -2.1847098 ]), 1.0, False, {})
# (array([ 0.10374257,  1.59713492, -0.20896105, -2.52350703]), 1.0, False, {})
# (array([ 0.13568527,  1.79326085, -0.25943119, -2.87228486]), 1.0, True, {})
# (array([-0.0386808 ,  0.2277983 , -0.04485057, -0.28281901]), 1.0, False, {})
# (array([-0.03412483,  0.42353032, -0.05050695, -0.58930345]), 1.0, False, {})
# (array([-0.02565423,  0.61932177, -0.06229302, -0.89745884]), 1.0, False, {})
# (array([-0.01326779,  0.81523031, -0.0802422 , -1.20905399]), 1.0, False, {})
# (array([ 0.00303682,  1.01129163, -0.10442328, -1.52576557]), 1.0, False, {})
# (array([ 0.02326265,  1.20750758, -0.13493859, -1.84913095]), 1.0, False, {})
# (array([ 0.0474128 ,  1.40383258, -0.17192121, -2.1804931 ]), 1.0, False, {})
# (array([ 0.07548945,  1.60015786, -0.21553107, -2.52093587]), 1.0, True, {})
# (array([-0.03632817,  0.23335625,  0.02792588, -0.30589206]), 1.0, False, {})
# (array([-0.03166105,  0.42806935,  0.02180804, -0.5896387 ]), 1.0, False, {})
# (array([-0.02309966,  0.23264894,  0.01001527, -0.29016672]), 1.0, False, {})
# (array([-0.01844668,  0.03738562,  0.00421193,  0.00565801]), 1.0, False, {})
# (array([-0.01769897, -0.15779649,  0.00432509,  0.29966687]), 1.0, False, {})
# (array([-0.0208549 , -0.35297982,  0.01031843,  0.5937107 ]), 1.0, False, {})
# (array([-0.0279145 , -0.54824467,  0.02219264,  0.88962595]), 1.0, False, {})
# (array([-0.03887939, -0.74366062,  0.03998516,  1.1892018 ]), 1.0, False, {})

# %%
def run_episode(env, parameters):  
    """Runs the env for a certain amount of steps with the given parameters. Returns the reward obtained"""
    observation = env.reset()
    totalreward = 0
    for _ in range(200):
        action = 0 if np.matmul(parameters,observation) < 0 else 1
        observation, reward, done, info = env.step(action)
        totalreward += reward
        if done:
            break
    return totalreward

# Random search: try random parameters between -1 and 1, see how long the game lasts with those parameters
bestparams = None  
bestreward = 0  
for _ in range(10000):  
    parameters = np.random.rand(4) * 2 - 1
    reward = run_episode(env,parameters)
    if reward > bestreward:
        bestreward = reward
        bestparams = parameters
        # considered solved if the agent lasts 200 timesteps
        if reward == 200:
            break
            
def show_episode(env, parameters):  
    """ Records the frames of the environment obtained using the given parameters... Returns RGB frames"""
    observation = env.reset()
    firstframe = env.render(mode = 'rgb_array')
    frames = [firstframe]
    
    for _ in range(200):
        action = 0 if np.matmul(parameters,observation) < 0 else 1
        observation, reward, done, info = env.step(action)
        frame = env.render(mode = 'rgb_array')
        frames.append(frame)
        if done:
            break
    return frames

frames = show_episode(env, bestparams)
display_frames_as_gif(frames, filename_gif="bestresultrandom.gif")
